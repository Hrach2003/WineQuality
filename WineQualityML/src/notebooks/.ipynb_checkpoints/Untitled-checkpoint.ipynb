# %%
import plotly.express as px
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/wineQuality(cleaned).csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19852 entries, 0 to 19851
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         19852 non-null  float64
#  1   volatile acidity      19852 non-null  float64
#  2   citric acid           19852 non-null  float64
#  3   residual sugar        19852 non-null  float64
#  4   chlorides             19852 non-null  float64
#  5   free sulfur dioxide   19852 non-null  float64
#  6   total sulfur dioxide  19852 non-null  float64
#  7   density               19852 non-null  float64
#  8   pH                    19852 non-null  float64
#  9   sulphates             19852 non-null  float64
#  10  alcohol               19852 non-null  float64
#  11  quality               19852 non-null  int64
# dtypes: float64(11), int64(1)
# memory usage: 1.8 MB

# %%
pca = PCA(n_components=3)
components = pca.fit_transform(df)

total_var = pca.explained_variance_ratio_.sum() * 100

fig = px.scatter_3d(df, x='alcohol', y='chlorides', z='residual sugar', color=df['quality'])
fig.show()
# components
